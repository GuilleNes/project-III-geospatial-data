# %%
import os
import requests
import json
from dotenv import load_dotenv
import pandas as pd
import pymongo
import geopandas as gpd
import functions as fun
import geopy
from geopy import distance
import numpy as np
import folium
from folium import Choropleth, Circle, Marker, Icon, Map
from folium.plugins import HeatMap, MarkerCluster

# %%
San_Francisco = 37.7871253,-122.4015358
Seattle = 47.6129432,-122.4821477
Chicago = 47.6065687,-122.3334623
London = 51.4621272,-0.1162654
Austin = 30.2663643,-97.744405
Cambridge = 42.3731956,-71.1198561
Paris = 48.8848037,2.3318758

# %% [markdown]
# # SAN FRANCISCO

# %%
token_foursquare = os.getenv("Token_foursquare")

# %%
#get_results(query, location, limit, radius, token):

# %% [markdown]
# - First we look for Starbucks close to the office and clean the results keeping only the columns that we are interested about

# %%
starbucks_SF = fun.get_results("starbucks", San_Francisco, 10, 1000, "fsq3BbaJEgNJ83hcrvS2q6PeMaQhIxmKaaREXp8m45uJ0Ac=")

# %%
df_SF = fun.clean_results_first(starbucks_SF, "Coffee")

# %% [markdown]
# - We look for preschools or kindergarten around the office and clean the results keeping only the columns that we are interested about

# %%
kinder_SF = fun.get_results("preschool", San_Francisco, 10, 3000, "fsq3BbaJEgNJ83hcrvS2q6PeMaQhIxmKaaREXp8m45uJ0Ac=")

# %%
df_SF = fun.clean_results(kinder_SF, df_SF, "Preschool")

# %% [markdown]
# - We look for nightclubs around the office and clean the results keeping only the columns that we are interested about

# %%
club_SF = fun.get_results("night club", San_Francisco, 10, 3000, "fsq3BbaJEgNJ83hcrvS2q6PeMaQhIxmKaaREXp8m45uJ0Ac=")

# %%
df_SF = fun.clean_results(club_SF, df_SF, "Club")

# %% [markdown]
# - We look for nightclubs around the office and clean the results keeping only the columns that we are interested about

# %%
vegan_SF = fun.get_results("vegan", San_Francisco, 10, 3000, "fsq3BbaJEgNJ83hcrvS2q6PeMaQhIxmKaaREXp8m45uJ0Ac=")

# %%
df_SF = fun.clean_results(vegan_SF, df_SF, "Vegan restaurant")

# %% [markdown]
# - We look for basketball arena (Chase Center) around the office and clean the results keeping only the columns that we are interested about

# %%
Basketball_SF = fun.get_results("Chase center", San_Francisco, 1, 5000, "fsq3BbaJEgNJ83hcrvS2q6PeMaQhIxmKaaREXp8m45uJ0Ac=")
df_SF = fun.clean_results(Basketball_SF, df_SF, "Basketball arena")

# %% [markdown]
# - We look for the closest Airport to office and clean the results keeping only the columns that we are interested about

# %%
Airports_SF = fun.get_results("Airport", San_Francisco, 1, 5000, "fsq3BbaJEgNJ83hcrvS2q6PeMaQhIxmKaaREXp8m45uJ0Ac=")
df_SF = fun.clean_results(Airports_SF, df_SF, "Airport")

# %%
df_SF = fun.add_company(df_SF, "662 Mission St, San Francisco, CA 94105", "Soma", 37.7871253, -122.4015358)

# %%
df_SF["Distance"] = df_SF.apply(fun.calc_distance_SF, axis = 1).round(2)

# %%
df_SF
# Out:
#                                             name  \
# 0                                        Company
# 1                                      Starbucks
# 2                                      Starbucks
# 3                                      Starbucks
# 4                                      Starbucks
# 5                                      Starbucks
# 6                                      Starbucks
# 7                                      Starbucks
# 8                                      Starbucks
# 9                                      Starbucks
# 10                                     Starbucks
# 11                True Sunshine Preschool Center
# 12                          Apple Tree Preschool
# 13                             Seabird Preschool
# 14                 Golden Gate Guppies Preschool
# 15  Yerba Buena Gardens Child Development Center
# 36  676 Geary St (at Leavenworth St), San Francisc...             Tenderloin
# 37  17 Kearny St (Market Street), San Francisco, C...     Financial District
# 38  555 Folsom St (at Essex St), San Francisco, CA...            Rincon Hill
# 39  212 Ritch St (at Bryant St), San Francisco, CA...            South Beach
# 40  300 Folsom St (at Beale St), San Francisco, CA...              Chinatown
# 41            1 Warriors Way, San Francisco, CA 94158            Mission Bay
# 42                            San Francisco, CA 94128           Civic Center
#
#           lat         lon          category  Distance
# 0   37.787125 -122.401536               NaN      0.00
# 1   37.788371 -122.393555            Coffee    716.46
# 2   37.784470 -122.404008            Coffee    366.45
# 3   37.784144 -122.407429            Coffee    615.61
# 4   37.793818 -122.396678            Coffee    857.26
# 5   37.786145 -122.405612            Coffee    375.18
# 6   37.789098 -122.408438            Coffee    646.20
# 7   37.789293 -122.406729            Coffee    516.86
# 8   37.794601 -122.402669            Coffee    835.73
# 9   37.790652 -122.403869            Coffee    442.11
# 10  37.790448 -122.405722            Coffee    521.51
# 11  37.792767 -122.407866         Preschool    838.45
# 12  37.777038 -122.405075         Preschool   1162.21
# 13  37.797109 -122.407907         Preschool   1242.11
# 14  37.789035 -122.434456         Preschool   2907.50
# 15  37.782460 -122.400807         Preschool    521.78
# 16  37.795777 -122.404818         Preschool   1002.85
# 17  37.779296 -122.411875         Preschool   1258.84
# 18  37.776344 -122.418868         Preschool   1939.89
# 19  37.771561 -122.391634         Preschool   1935.26
# 20  37.785183 -122.423333         Preschool   1932.11
# 21  37.781406 -122.409490              Club    945.47
# 22  37.775367 -122.409851              Club   1496.60
# 23  37.767481 -122.406590              Club   2225.37
# 24  37.765554 -122.413429              Club   2613.47
# 25  37.775283 -122.409986              Club   1510.56
# 26  37.771002 -122.412675              Club   2040.96
# 27  37.771462 -122.413921              Club   2052.52
# 28  37.771002 -122.412675              Club   2040.96
# 29  37.767936 -122.406617              Club   2176.40
# 30  37.778128 -122.405784              Club   1066.45
# 31  37.795717 -122.405173  Vegan restaurant   1005.99
# 32  37.781359 -122.416942  Vegan restaurant   1500.46
# 33  37.783391 -122.418998  Vegan restaurant   1593.07
# 34  37.788531 -122.415000  Vegan restaurant   1196.21
# 35  37.795174 -122.407148  Vegan restaurant   1020.99
# 36  37.786727 -122.414249  Vegan restaurant   1120.73
# 37  37.788248 -122.403728  Vegan restaurant    229.82
# 38  37.786473 -122.395307  Vegan restaurant    553.43
# 39  37.780651 -122.396255  Vegan restaurant    856.03
# 40  37.788794 -122.393150  Vegan restaurant    761.53
# 41  37.767935 -122.387335  Basketball arena   2470.21
# 42  37.785876 -122.408407           Airport    620.94

# %%
SF_map = Map(location = San_Francisco, zoom_start = 12)

# %%
for index, row in df_SF.iterrows():
    
    #1. MARKER without icon
    district = {"location": [row["lat"], row["lon"]], "tooltip": row["name"]}
    
    #2. Icon
    if row["category"] == "Coffee":        
        icon = Icon (
            color="white",
            opacity = 0.6,
            prefix = "fa",
            icon="coffee",
            icon_color = "black"
        )
    elif row["category"] == "Preschool":
        icon = Icon (
            color="pink",
            opacity = 0.6,
            prefix = "fa",
            icon="graduation-cap",
            icon_color = "yellow"
        )
    elif row["category"] == "Club":
        icon = Icon (
            color="darkpurple",
            opacity = 0.6,
            prefix = "fa",
            icon="glass",
            icon_color = "white"
        )
    elif row["category"] == "Vegan restaurant":
        icon = Icon (
            color="green",
            opacity = 0.6,
            prefix = "fa",
            icon="cutlery",
            icon_color = "white"
        )
    elif row["category"] == "Basketball arena":
        icon = Icon (
            color="orange",
            opacity = 0.6,
            prefix = "fa",
            icon="futbol-o",
            icon_color = "white"
        )
    elif row["category"] == "Airport":
        icon = Icon (
            color="blue",
            opacity = 0.6,
            prefix = "fa",
            icon="plane",
            icon_color = "white"
            
        )
    else:
        row["category"] == "Company",
        icon = Icon (
        color="black",
        opacity = 0.9,
        prefix = "fa",
        icon = "briefcase",
        icon_color = "white",
        icon_size=(30, 30)
        )
            
    #3. Marker
    marker = Marker(**district, icon = icon, radius = 2)
    
    #4. Add the Marker
    marker.add_to(SF_map)

# %%
SF_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fc1d8511137c4f523fe4fcfcc9ed5875 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fc1d8511137c4f523fe4fcfcc9ed5875&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_fc1d8511137c4f523fe4fcfcc9ed5875 = L.map(
#                 &quot;map_fc1d8511137c4f523fe4fcfcc9ed5875&quot;,
#                 {
#                     center: [37.7871253, -122.4015358],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0969cd294f1b9d3fa2644c893f7fd7f4 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_fc1d8511137c4f523fe4fcfcc9ed5875);
#
#
#             var marker_83e291fe014f35d9a3e6511cb93be030 = L.marker(
#                 [37.7871253, -122.4015358],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_fc1d8511137c4f523fe4fcfcc9ed5875);
#
#
#             var icon_611f8a657a7a7489964a6f9c5cde938f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;briefcase&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;iconSize&quot;: [30, 30], &quot;markerColor&quot;: &quot;black&quot;, &quot;opacity&quot;: 0.9, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_83e291fe014f35d9a3e6511cb93be030.setIcon(icon_611f8a657a7a7489964a6f9c5cde938f);
#
#
#             marker_83e291fe014f35d9a3e6511cb93be030.bindTooltip(
#                 `&lt;div&gt;
#                      Company
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_4bb4916aebc4b42701ef92c252823c25 = L.marker(
#                 [37.788371, -122.393555],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_fc1d8511137c4f523fe4fcfcc9ed5875);
#
#
#             var icon_79337948ef5584465e86a03221975aa1 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;coffee&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;markerColor&quot;: &quot;white&quot;, &quot;opacity&quot;: 0.6, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_4bb4916aebc4b42701ef92c252823c25.setIcon(icon_79337948ef5584465e86a03221975aa1);
#
#
#             marker_4bb4916aebc4b42701ef92c252823c25.bindTooltip(
#                 `&lt;div&gt;
#                      Starbucks
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_60e9ff77ed0cf2634e418af1fab05cdd = L.marker(
#                 [37.78447, -122.404008],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_fc1d8511137c4f523fe4fcfcc9ed5875);
#
#
#             var icon_71248850af8adde29d0c06d7dd122e8c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;coffee&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;markerColor&quot;: &quot;white&quot;, &quot;opacity&quot;: 0.6, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_60e9ff77ed0cf2634e418af1fab05cdd.setIcon(icon_71248850af8adde29d0c06d7dd122e8c);
#
#
#             marker_60e9ff77ed0cf2634e418af1fab05cdd.bindTooltip(
#                 `&lt;div&gt;
#                      Starbucks
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_bee35c05d76fbaa2118f08f51aa38018 = L.marker(
#                 [37.784144, -122.407429],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_fc1d8511137c4f523fe4fcfcc9ed5875);
#
#
#             var icon_3d6c82aff6fc2cd030bf195ae5f3b6b9 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;coffee&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;markerColor&quot;: &quot;white&quot;, &quot;opacity&quot;: 0.6, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_bee35c05d76fbaa2118f08f51aa38018.setIcon(icon_3d6c82aff6fc2cd030bf195ae5f3b6b9);
#
#
#             marker_bee35c05d76fbaa2118f08f51aa38018.bindTooltip(
#                 `&lt;div&gt;
#                      Starbucks
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_383aa33f131341859c9fb8a9549dfaf2 = L.marker(
#                 [37.793818, -122.396678],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_fc1d8511137c4f523fe4fcfcc9ed5875);
#
#
#             var icon_3368bfcb33980ddeff4bdf1167a03fb8 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;coffee&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;markerColor&quot;: &quot;white&quot;, &quot;opacity&quot;: 0.6, &quot;pr
