# %%
from pymongo import MongoClient
import pandas as pd
import functions as fun
import os
from dotenv import load_dotenv
from folium import Choropleth, Circle, Marker, Icon, Map
from folium.plugins import HeatMap, MarkerCluster
from geopy import distance

# %% [markdown]
# # Connecting to the MongoDB

# %%
# First of all, we connect with MongoDB

client = MongoClient("localhost:27017")
db = client["Ironhack"]
c = db.get_collection("Companies")

# %%
# We extract the data from the DB. In this case we are required to extract it according to certain parameters

condition_one = {"description": {"$regex": "design"}}
condition_two = {"tag_list": {"$regex": "design"}}
condition_three = {"name": {"$regex": "design"}}
condition_four = {"category_code": {"$regex": "design"}}
condition_five = {"total_money_raised": {"$regex": "M"}}
condition_six = {"total_money_raised": {"$regex": "B"}}

projection = {"name": 1, "number_of_employees": 1, "offices": 1,"_id":0}
result = list(c.find({
    "$or": [condition_one, condition_two, condition_three, condition_four, condition_five, condition_six],
    "number_of_employees": {"$gte": 100}
}, projection))


df = pd.DataFrame(result)

# %%
# Once we got the df, we get all the data that we need from it applying different functions and clean the df:

list_offices = df["offices"]

fun.get_info(list_offices, df,  "Country", "country_code")

fun.get_info(list_offices, df,"Zip_code", "zip_code")

fun.get_info(list_offices, df,"City", "city")

fun.get_info(list_offices, df,"Address", "address1")

fun.get_info(list_offices, df,"Lat", "latitude")

fun.get_info(list_offices, df,"Long", "longitude")

fun.drop_column(df, "offices")

fun.drop_nan(df)

df
# Out:
#            name  number_of_employees Country    Zip_code           City  \
# 0      Facebook                 5299     USA       94025     Menlo Park
# 1       Twitter                 1300     USA       94103  San Francisco
# 2          eBay                15000     USA       95125       San Jose
# 3         Cisco                63000     USA       95134       San Jose
# 4        Yahoo!                13600     USA       94089      Sunnyvale
# ..          ...                  ...     ...         ...            ...
# 380    Mashable                  100     USA  10010-3646       New York
# 381  SpringSoft                  400     USA       95110       San Jose
# 382  MentorMate                  216     USA       55408    Minneapolis
# 383   InfoLogix                  206     USA       19040        Hatboro
# 384  smartFOCUS                  550     GBR     BS1 6NP        Bristol
#
#                            Address        Lat        Long
# 0                 1601 Willow Road   37.41605 -122.151801
# 1                  1355 Market St.  37.776805 -122.416924
# 2             2145 Hamilton Avenue  37.295005 -121.930035
# 3              170 West Tasman Dr.  37.408802  -121.95377
# 4                 701 First Avenue  37.418531 -122.025485
# ..                             ...        ...         ...
# 380             304 Park Ave South  40.740154  -73.986742
# 381  2025 Gateway Place, Suite 400   37.37027 -121.924053
# 382           3036 Hennepin Avenue  44.948786  -93.161038
# 383      101 East County Line Road  40.192329  -75.106923
# 384            One Redcliff Street  51.452512   -2.590974
#
# [385 rows x 8 columns]

# %% [markdown]
# - Once we got the df clean, we have a deeper look to the different categories on it in order to have a clearer view of the next steps that we need to take and specially focusing on the different cities where the companies are located.

# %%
fun.value_counts(df, "City_count", "City")

# %%
# We reduce the number of cities keeping those with at least 5 companies.

df = fun.keep_value(df, "City_count", 5.0)

# %%
df["City"].value_counts()
# Out:
# San Francisco    50
# New York         30
# San Jose         16
# Mountain View    16
# Palo Alto        11
# San Mateo        11
# Sunnyvale         9
# Seattle           8
# London            8
# Redwood City      7
# Chicago           7
# Cambridge         6
# null              6
# Paris             6
# Austin            5
# Waltham           5
# Los Angeles       5
# Name: City, dtype: int64

# %% [markdown]
# # Trying to keep different cities in different areas and different locations, we are going to focus on the cities of San Francisco , Seattle, Chicago , London and Cambridge (USA).

# %%
San_Francisco = 37.7871253,-122.4015358
sub_SF = fun.do_subset(df, "San Francisco")

Seattle = 47.6251419,-122.3268577
sub_SE = fun.do_subset(df, "Seattle")

Chicago = 41.869276, -87.626694
sub_CH = fun.do_subset(df, "Chicago")

London = 51.4621272,-0.1162654
sub_LO = fun.do_subset(df, "London")

Cambridge = 42.3731956,-71.1198561
sub_CA = fun.do_subset(df, "Cambridge")

# %%
load_dotenv()
token_foursquare = os.getenv("Token_foursquare")

# %% [markdown]
# - First we look for Starbucks close to the office and clean the results keeping only the columns that we are interested about. There are many for each of our locations

# %%
starbucks_SF = fun.get_results("starbucks", San_Francisco, 10, 3000, token_foursquare)
df_SF = fun.clean_results_first(starbucks_SF, "Coffee")

starbucks_SE = fun.get_results("starbucks", Seattle, 10, 3000, token_foursquare)
df_SE = fun.clean_results_first(starbucks_SE, "Coffee")

starbucks_LO = fun.get_results("starbucks", London, 10, 3000, token_foursquare)
df_LO = fun.clean_results_first_lo(starbucks_LO, "Coffee")

starbucks_CA = fun.get_results("starbucks", Cambridge, 10, 3000, token_foursquare)
df_CA = fun.clean_results_first(starbucks_CA, "Coffee")

starbucks_CH = fun.get_results("starbucks", Chicago, 10, 3000, token_foursquare)
df_CH = fun.clean_results_first(starbucks_CH, "Coffee")

# %% [markdown]
# - We look for preschools or kindergarten around the office and clean the results keeping only the columns that we are interested about. There are also enough within a short distance from the offices.

# %%
kinder_SF = fun.get_results("preschool", San_Francisco, 10, 3000, token_foursquare)
df_SF = fun.clean_results(kinder_SF, df_SF, "Preschool")

kinder_SE = fun.get_results("preschool", Seattle, 10, 3000, token_foursquare)
df_SE = fun.clean_results(kinder_SE, df_SE, "Preschool")

kinder_LO = fun.get_results("Nursery school", London, 5, 3000, token_foursquare)
df_LO = fun.clean_results_lo(kinder_LO, df_LO, "Preschool")

kinder_CA = fun.get_results("preschool", Cambridge, 10, 3000, token_foursquare)
df_CA = fun.clean_results(kinder_CA, df_CA, "Preschool")

kinder_CH = fun.get_results("preschool", Chicago, 10, 3000, token_foursquare)
df_CH = fun.clean_results(kinder_CH, df_CH, "Preschool")

# %% [markdown]
# - We look for nightclubs around the office and clean the results keeping only the columns that we are interested about

# %%
club_SF = fun.get_results("night club", San_Francisco, 10, 3000, token_foursquare)
df_SF = fun.clean_results(club_SF, df_SF, "Club")

club_SE = fun.get_results("night club", Seattle, 10, 3000, token_foursquare)
df_SE = fun.clean_results(club_SE, df_SE, "Club")

club_LO = fun.get_results("night club", London, 5, 3000, token_foursquare)
df_LO = fun.clean_results_lo(club_LO, df_LO, "Club")

club_CA = fun.get_results("night club", Cambridge, 10, 3000, token_foursquare)
df_CA = fun.clean_results(club_CA, df_CA, "Club")

club_CH = fun.get_results("night club", Chicago, 10, 3000, token_foursquare)
df_CH = fun.clean_results(club_CH, df_CH, "Club")

# %% [markdown]
# - We look for vegan restaurants around the office. There are less and some that are not explicitely "vegans".

# %%
vegan_SF = fun.get_results("vegan", San_Francisco, 10, 3000, token_foursquare)
df_SF = fun.clean_results(vegan_SF, df_SF, "Vegan restaurant")

vegan_SE = fun.get_results("vegan", Seattle, 10, 3000, token_foursquare)
df_SE = fun.clean_results(vegan_SE, df_SE, "Vegan restaurant")

vegan_LO = fun.get_results("vegan", London, 10, 3000, token_foursquare)
df_LO = fun.clean_results_lo(vegan_LO, df_LO, "Vegan restaurant")

vegan_CA = fun.get_results("vegan", Cambridge, 10, 3000, token_foursquare)
df_CA = fun.clean_results(vegan_CA, df_CA, "Vegan restaurant")

vegan_CH = fun.get_results("vegan", Chicago, 10, 3000, token_foursquare)
df_CH = fun.clean_results(vegan_CH, df_CH, "Vegan restaurant")

# %% [markdown]
# - We look for basketball arenas. Some of them are from major NBA teams, so we look for the actual name of its stadiums. However in Seattle, there is no local team at the moment (we pray for the Supersonics return soon). In London there is an arena, with a local team, however, is not within a "short" distance from the office.

# %%
Basketball_SF = fun.get_results("Chase center", San_Francisco, 1, 5000, token_foursquare)
df_SF = fun.clean_results(Basketball_SF, df_SF, "Basketball arena")

Basketball_SE = fun.get_results("Climate Pledge Arena", Seattle, 1, 5000, token_foursquare)
df_SE = fun.clean_results(Basketball_SE, df_SE, "Basketball arena")

Basketball_LO = fun.get_results("Basketball arena", London, 1, 5000, token_foursquare)

Basketball_CA = fun.get_results("TD Garden", Cambridge, 1, 5000, token_foursquare)
df_CA = fun.clean_results(Basketball_CA, df_CA, "Basketball arena")

Basketball_CH = fun.get_results("United center", Chicago, 1, 5000, token_foursquare)
df_CH = fun.clean_results(Basketball_CH, df_CH, "Basketball arena")

# %% [markdown]
# - We look for dog hairdressers around the office; we did not find any result for the cities of London and Cambridge.

# %%
pet_SF = fun.get_results("pet grooming", San_Francisco, 5, 3000, token_foursquare)
df_SF = fun.clean_results(pet_SF, df_SF, "Pet hairdresser")

pet_SE = fun.get_results("pet grooming", Seattle, 5, 3000, token_foursquare)
df_SE = fun.clean_results(pet_SE, df_SE, "Pet hairdresser")

pet_LO = fun.get_results("dog grooming", London, 5, 3000, token_foursquare)
df_LO = fun.clean_results_lo(pet_LO, df_LO, "Pet hairdresser")

pet_CA = fun.get_results("dog grooming", Cambridge, 5, 3000, token_foursquare)
df_CA = fun.clean_results_lo(pet_CA, df_CA, "Pet hairdresser")

pet_CH = fun.get_results("pet grooming", Chicago, 5, 3000, token_foursquare)
df_CH = fun.clean_results(pet_CH, df_CH, "Pet hairdresser")

# %% [markdown]
# - We look for the closest Airport to office. In all the cities except Seattle, we look for two airports.

# %%
Airports_SF = fun.get_results_airport("Airport", San_Francisco, 2, 30000, token_foursquare)
df_SF = fun.clean_results_lo(Airports_SF, df_SF, "Airport")

Airports_SE = fun.get_results_airport("Seattle tacoma airport", Seattle, 1, 30000, token_foursquare)
df_SE = fun.clean_results_lo(Airports_SE, df_SE, "Airport")

Airports_LO = fun.get_results_airport("Airport", London, 2, 30000, token_foursquare)
df_LO = fun.clean_results_lo(Airports_LO, df_LO, "Airport")

Airports_CA = fun.get_results_airport("Airport", Cambridge, 2, 30000, token_foursquare)
df_CA = fun.clean_results_lo(Airports_CA, df_CA, "Airport")

Airports_CH = fun.get_results_airport("Airport", Chicago, 2, 30000, token_foursquare)
df_CH = fun.clean_results(Airports_CH, df_CH, "Airport")

# %% [markdown]
# - We add the data of the new office that we have selected. This is a random location close to the places that we have looked for and the companies from the MongoDB

# %%
df_SF = fun.add_company(df_SF, "662 Mission St, San Francisco, CA 94105", "Soma", 37.7871253, -122.4015358)

df_SE = fun.add_company(df_SE, "South Lake Union, Seattle, Washington 98109", "South Lake Union", 47.624730, -122.335911)

df_LO = fun.add_company(df_LO, "1-2 More London Pl, London", "Southwark", 51.505024, -0.080416)

df_CA = fun.add_company(df_CA, "5, John F. Kennedy St, Cambridge, MA 02138", "West Cambridge", 42.3731956,-71.1198561)

df_CH = fun.add_company(df_CH, "118 S Holden Ct, Chicago, IL 60605", "Dearborn Park", 41.869276, -87.626694)

# %% [markdown]
# - We create a new row with the distance from the office to the diferent places (we do not include the distance to the other companies here, as we consider that is enough sharing the city)

# %%
df_SF["Distance"] = df_SF.apply(fun.calc_distance_SF, axis = 1).round(2)

df_SE["Distance"] = df_SE.apply(fun.calc_distance_SE, axis = 1).round(2)

df_LO["Distance"] = df_LO.apply(fun.calc_distance_LO, axis = 1).round(2)

df_CA["Distance"] = df_CA.apply(fun.calc_distance_CA, axis = 1).round(2)

df_CH["Distance"] = df_CH.apply(fun.calc_distance_CH, axis = 1).round(2)

# %%
df_SF
# Out:
#                                             name  \
# 0                                        Company
# 1                                      Starbucks
# 2                                      Starbucks
# 3                                      Starbucks
# 4                                      Starbucks
# 5                                      Starbucks
# 6                                      Starbucks
# 7                                      Starbucks
# 8                                      Starbucks
# 9                                      Starbucks
# 10                                     Starbucks
# 11                True Sunshine Preschool Center
# 12                          Apple Tree Preschool
# 13                             Seabird Preschool
# 14                 Golden Gate Guppies Preschool
# 15  Yerba Buena Gardens Child Development Center
# 16                Saint Marys Chinese Day School
# 17                    KinderCare Learning Center
# 18                                 LePort School
# 19                      826 Valencia Mission Bay
# 20                  Montessori House Of Children
# 21                                      Club Six
# 22                                      Cat Club
# 23                            The Great Northern
# 24                                  Jolene's Bar
# 25                                F8 1192 Folsom
# 26                                    DNA Lounge
# 27                               Audio Nightclub
# 28                          Bootie San Francisco
# 29                        Breakfast of Champions
# 30                                   1015 Folsom
# 31                   Enjoy Vegetarian Restaurant
# 32                   Golden Era Vegan Restaurant
# 33               Thai Idea Vegetarian Restaurant
# 34                                Chisme Cantina
# 35      The Lucky Creation Vegetarian Restaurant
# 36                                  Mensho Tokyo
# 37                                Asha Tea House
# 38                                    DragonEats
# 39                                   Darwin Cafe
# 40                               Mazarine Coffee
# 41                          Chase Center Stadium
# 42                   Bernie's Grooming City Dogs
# 43       Nova Express Personal Grooming Services
# 44     Via V'dell Executive Grooming Barber Shop
# 45        Details Barbershop and Grooming Lounge
# 46                 Tae Hee's Grooming Pet Supply
# 47     San Francisco International Airport (SFO)
# 48           Oakland International Airport (OAK)
#
#                                               address           neighborhood  \
# 0             662 Mission St, San Francisco, CA 94105                   Soma
# 1   299 Fremont St (Folsom St), San Francisco, CA ...              Chinatown
# 2   789 Mission St (at 4th St), San Francisco, CA ...           Civic Center
# 3    7 Drumm St (California), San Francisco, CA 94111              Chinatown
# 4   865 Market St (5th street), San Francisco, CA ...           Civic Center
# 5   780 Market St (at 4th St), San Francisco, CA 9...           Civic Center
# 6   462 Powell St (at Sutter St), San Francisco, C...              Chinatown
# 7   390 Stockton St (at Sutter St), San Francisco,...              Chinatown
# 8   74 New Montgomery St (at Jessie St), San Franc...     Financial District
# 9   565 Clay St (at Montgomery St), San Francisco,...              Chinatown
# 10  264 Kearny St (at Bush St), San Francisco, CA ...              Chinatown
# 11  777 Stockton St (Sacramento), San Francisco, C...              Chinatown
# 12  85 Columbia Sq (btwn Folsom & Harrison St), Sa...        South Of Market
# 13               3 Stark Aly, San Francisco, CA 94133              Chinatown
# 14  2426 California St (Fillmore Street), San Fran...  Lower Pacific Heights
# 15             790 Folsom St, San Francisco, CA 94107            South Beach
# 16  838 Kearny St (btwn Washington & Jackson St), ...              Chinatown
# 17     90 7th St (Stevenson), San Francisco, CA 94103           Civic Center
# 18                50 Fell St, San Francisco, CA 94102           Civic Center
# 19               1310 4th St, San Francisco, CA 94158            Mission Bay
# 20          1187 Franklin St, San Francisco, CA 94109         Cathedral Hill
# 21  60 6th St (btwn Market & Mission St), San Fran...           Civic Center
# 22  1190 Folsom St (at 8th St), San Francisco, CA ...           Civic Center
# 23  119 Utah St (at 15th St), San Francisco, CA 94103          Inner Mission
# 24              2700 16th St, San Francisco, CA 94103          Inner Mission
# 25      1192 Folsom St (8th), San Francisco, CA 94103           Civic Center
# 26  375 11th St (at Harrison St), San Francisco, C...           Civic Center
# 27  316 11th St (btwn Folsom & Harrison), San Fran...           Civic Center
# 28  375 11th St (at Harrison St), San Francisco, C...           Civic Center
# 29  817 Terry A Francois Blvd (between Illinois St...          Inner Mission
# 30  1015 Folsom St (at 6th St), San Francisco, CA ...        South Of Market
# 31  839 Kearny St (at Washington St.), San Francis...              Chinatown
# 32       395 Golden Gate Ave, San Francisco, CA 94102           Civic Center
# 33  710 Polk St (at Eddy St), San Francisco, CA 94109           Civic Center
# 34  882 Sutter St (Leavenworth St), San Francisco,...          Little Saigon
# 35  854 Washington St (btwn Stockton & Ross), San ...              Chinatown
# 36  676 Geary St (at Leavenworth St), San Francisc...             Tenderloin
# 37  17 Kearny St (Market Street), San Francisco, C...     Financial District
# 38  555 Folsom St (at Essex St), San Francisco, CA...            Rincon Hill
# 39  212 Ritch St (at Bryant St), San Francisco, CA...            South Beach
# 40  720 Market St (btwn O'Farrell & Kearny St), Sa...     Financial District
# 41            1 Warriors Way, San Francisco, CA 94158            Mission Bay
# 42  177 Brannan St (Delancey St), San Francisco, C...            Mission Bay
# 43  21 Columbus Ave (Washington), San Francisco, C...              Chinatown
# 44              166 Geary St, San Francisco, CA 94108              Chinatown
# 45              166 Geary St, San Francisco, CA 94108              Chinatown
# 46               580 Bush St, San Francisco, CA 94108              Chinatown
# 47                at Link Rd, San Francisco, CA 94128                      S
# 48                    1 Airport Dr, Oakland, CA 94621                      O
#
#           lat         lon          category  Distance
# 0   37.787125 -122.401536               NaN      0.00
# 1   37.788371 -122.393555            Coffee    716.46
# 2   37.784470 -122.404008            Coffee    366.45
# 3   37.793818 -122.396678            Coffee    857.26
# 4   37.784144 -122.407429            Coffee    615.61
# 5   37.786145 -122.405612            Coffee    375.18
# 6   37.789098 -122.408438            Coffee    646.20
# 7   37.789293 -122.406729            Coffee    516.86
# 8   37.787664 -122.401113            Coffee     70.44
# 9   37.794601 -122.402669            Coffee    835.73
# 10  37.790652 -122.403869            Coffee    442.11
# 11  37.792767 -122.407866         Preschool    838.45
# 12  37.777038 -122.405075         Preschool   1162.21
# 13  37.797109 -122.407907         Preschool   1242.11
# 14  37.789035 -122.434456         Preschool   2907.50
# 15  37.782460 -122.400807         Preschool    521.78
# 16  37.795777 -122.404818         Preschool   1002.85
# 17  37.779296 -122.411875         Preschool   1258.84
# 18  37.776344 -122.418868         Preschool   1939.89
# 19  37.771561 -122.391634         Preschool   1935.26
# 20  37.785183 -122.423333         Preschool   1932.11
# 21  37.781406 -122.409490              Club    945.47
# 22  37.775367 -122.409851              Club   1496.60
# 23  37.767481 -122.406590              Club   2225.37
# 24  37.765554 -122.413429              Club   2613.47
# 25  37.775283 -122.409986              Club   1510.56
# 26  37.771002 -122.412675              Club   2040.96
# 27  37.771462 -122.413921              Club   2052.52
# 28  37.771002 -122.412675              Club   2040.96
# 29  37.767936 -122.406617              Club   2176.40
# 30  37.778128 -122.405784              Club   1066.45
# 31  37.795717 -122.405173  Vegan restaurant   1005.99
# 32  37.781359 -122.416942  Vegan restaurant   1500.46
# 33  37.783391 -122.418998  Vegan restaurant   1593.07
# 34  37.788531 -122.415000  Vegan restaurant   1196.21
# 35  37.795174 -122.407148  Vegan restaurant   1020.99
# 36  37.786727 -122.414249  Vegan restaurant   1120.73
# 37  37.788248 -122.403728  Vegan restaurant    229.82
# 38  37.786473 -122.395307  Vegan restaurant    553.43
# 39  37.780651 -122.396255  Vegan restaurant    856.03
# 40  37.787473 -122.404041  Vegan restaurant    224.02
# 41  37.767935 -122.387335  Basketball arena   2470.21
# 42  37.783824 -122.389344   Pet hairdresser   1134.74
# 43  37.795567 -122.403480   Pet hairdresser    952.49
# 44  37.787749 -122.405993   Pet hairdresser    398.67
# 45  37.787879 -122.406001   Pet hairdresser    402.12
# 46  37.790556 -122.406876   Pet hairdresser    605.19
# 47  37.624123 -122.395506           Airport  18099.59
# 48  37.711700 -122.212997           Airport  18605.79

# %% [markdown]
# - Then we create the base maps where we will add the different layers:

# %%
SF_map = Map(location = San_Francisco, zoom_start = 12)
SE_map = Map(location = Seattle, zoom_start = 12)
LO_map = Map(location = London, zoom_start = 12)
CA_map = Map(location = Cambridge, zoom_start = 12)
CH_map = Map(location = Chicago, zoom_start = 12)

# %% [markdown]
# - We create select the Icons and select the categories that we want to be displayed on the map

# %%
fun.mapping_results(df_SF, SF_map)
fun.mapping_results(df_SE, SE_map)
fun.mapping_results(df_LO, LO_map)
fun.mapping_results(df_CA, CA_map)
fun.mapping_results(df_CH, CH_map)

# %% [markdown]
# - Then we add the companies from the MongoDB to the map

# %%
fun.mapping_companies(sub_SF, SF_map)
fun.mapping_companies(sub_SE, SE_map)
fun.mapping_companies(sub_LO, LO_map)
fun.mapping_companies(sub_CA, CA_map)
fun.mapping_companies(sub_CH, CH_map)

# %% [markdown]
# - And here we got the maps!!

# %%
SF_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9daade2bfdd760383618b7cdb22c3dc4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9daade2bfdd760383618b7cdb22c3dc4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_9daade2bfdd760383618b7cdb22c3dc4 = L.map(
#                 &quot;map_9daade2bfdd760383618b7cdb22c3dc4&quot;,
#                 {
#                     center: [37.7871253, -122.4015358],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7dc74b446abcfcb3151bea02023b2eca = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_9daade2bfdd760383618b7cdb22c3dc4);
#
#
#             var marker_1fa8d55496b3e98f3393f4aa044b3db3 = L.marker(
#                 [37.7871253, -122.4015358],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_9daade2bfdd760383618b7cdb22c3dc4);
#
#
#             var icon_ab33397cf1b8ffd817f7ee438d8ca1a6 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;briefcase&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;iconSize&quot;: [30, 30], &quot;markerColor&quot;: &quot;black&quot;, &quot;opacity&quot;: 0.9, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_1fa8d55496b3e98f3393f4aa044b3db3.setIcon(icon_ab33397cf1b8ffd817f7ee438d8ca1a6);
#
#
#             marker_1fa8d55496b3e98f3393f4aa044b3db3.bindTooltip(
#                 `&lt;div&gt;
#                      Company
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_9d1d1b3889e26eadc6c0f7443112c92a = L.marker(
#                 [37.788371, -122.393555],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_9daade2bfdd760383618b7cdb22c3dc4);
#
#
#             var icon_4f5f4d65694479879958f797b4e04de4 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;coffee&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;markerColor&quot;: &quot;white&quot;, &quot;opacity&quot;: 0.6, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_9d1d1b3889e26eadc6c0f7443112c92a.setIcon(icon_4f5f4d65694479879958f797b4e04de4);
#
#
#             marker_9d1d1b3889e26eadc6c0f7443112c92a.bindTooltip(
#                 `&lt;div&gt;
#                      Starbucks
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_dc2bcda7d33a12cec54eab1526a75c3d = L.marker(
#                 [37.78447, -122.404008],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_9daade2bfdd760383618b7cdb22c3dc4);
#
#
#             var icon_cc458f21d04f6d4b68a8e06357de456a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;coffee&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;markerColor&quot;: &quot;white&quot;, &quot;opacity&quot;: 0.6, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_dc2bcda7d33a12cec54eab1526a75c3d.setIcon(icon_cc458f21d04f6d4b68a8e06357de456a);
#
#
#             marker_dc2bcda7d33a12cec54eab1526a75c3d.bindTooltip(
#                 `&lt;div&gt;
#                      Starbucks
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_968ada869e6385821bbd657d5a403f2d = L.marker(
#                 [37.793818, -122.396678],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_9daade2bfdd760383618b7cdb22c3dc4);
#
#
#             var icon_7b497c1f29f5fabd303f4925a0c62379 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;coffee&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;markerColor&quot;: &quot;white&quot;, &quot;opacity&quot;: 0.6, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_968ada869e6385821bbd657d5a403f2d.setIcon(icon_7b497c1f29f5fabd303f4925a0c62379);
#
#
#             marker_968ada869e6385821bbd657d5a403f2d.bindTooltip(
#                 `&lt;div&gt;
#                      Starbucks
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_9d16d394e26e44d1ba02eb36d19591ee = L.marker(
#                 [37.784144, -122.407429],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_9daade2bfdd760383618b7cdb22c3dc4);
#
#
#             var icon_e1474ee078526a4f6f334242a178bf55 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;coffee&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;markerColor&quot;: &quot;white&quot;, &quot;opacity&quot;: 0.6, &quot;pr

# %%
SE_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ef3679f4afb93bd2025f3d12c8161742 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ef3679f4afb93bd2025f3d12c8161742&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_ef3679f4afb93bd2025f3d12c8161742 = L.map(
#                 &quot;map_ef3679f4afb93bd2025f3d12c8161742&quot;,
#                 {
#                     center: [47.6251419, -122.3268577],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3acdc85bf9ee2209a43f06bde467dd4a = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ef3679f4afb93bd2025f3d12c8161742);
#
#
#             var marker_6d1cef23a62bb2676a968c1791b60db7 = L.marker(
#                 [47.62473, -122.335911],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_ef3679f4afb93bd2025f3d12c8161742);
#
#
#             var icon_72bb83e53cdca610069f5c72090279e6 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;briefcase&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;iconSize&quot;: [30, 30], &quot;markerColor&quot;: &quot;black&quot;, &quot;opacity&quot;: 0.9, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_6d1cef23a62bb2676a968c1791b60db7.setIcon(icon_72bb83e53cdca610069f5c72090279e6);
#
#
#             marker_6d1cef23a62bb2676a968c1791b60db7.bindTooltip(
#                 `&lt;div&gt;
#                      Company
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_31ff2bd3854aad02a38bc1506cce97af = L.marker(
#                 [47.623015, -122.320684],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_ef3679f4afb93bd2025f3d12c8161742);
#
#
#             var icon_0a47418a9e13ebabf5eb6104e2e7d32f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;coffee&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;markerColor&quot;: &quot;white&quot;, &quot;opacity&quot;: 0.6, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_31ff2bd3854aad02a38bc1506cce97af.setIcon(icon_0a47418a9e13ebabf5eb6104e2e7d32f);
#
#
#             marker_31ff2bd3854aad02a38bc1506cce97af.bindTooltip(
#                 `&lt;div&gt;
#                      Starbucks
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_ee066c7226bd6b2c10acbc941eb3fe19 = L.marker(
#                 [47.624391, -122.3389],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_ef3679f4afb93bd2025f3d12c8161742);
#
#
#             var icon_1a43c56c8aeb227db7c7f518f8c538c4 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;coffee&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;markerColor&quot;: &quot;white&quot;, &quot;opacity&quot;: 0.6, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_ee066c7226bd6b2c10acbc941eb3fe19.setIcon(icon_1a43c56c8aeb227db7c7f518f8c538c4);
#
#
#             marker_ee066c7226bd6b2c10acbc941eb3fe19.bindTooltip(
#                 `&lt;div&gt;
#                      Starbucks
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_b4073d9f79a41daf9ac50d67888a3f6e = L.marker(
#                 [47.612305, -122.333717],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_ef3679f4afb93bd2025f3d12c8161742);
#
#
#             var icon_2e631feaadaa124eaea8c29cafc4bbf3 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;coffee&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;markerColor&quot;: &quot;white&quot;, &quot;opacity&quot;: 0.6, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_b4073d9f79a41daf9ac50d67888a3f6e.setIcon(icon_2e631feaadaa124eaea8c29cafc4bbf3);
#
#
#             marker_b4073d9f79a41daf9ac50d67888a3f6e.bindTooltip(
#                 `&lt;div&gt;
#                      Starbucks
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_0421bd6da27a44aa027653e6c737c06e = L.marker(
#                 [47.615023, -122.338462],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_ef3679f4afb93bd2025f3d12c8161742);
#
#
#             var icon_76a6b8fb3e088efafe29302d1bb7ccb2 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;coffee&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;markerColor&quot;: &quot;white&quot;, &quot;opacity&quot;: 0.6, &quot;prefix

# %%
LO_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4568dc15835190d3eb5f7c3094404e1f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4568dc15835190d3eb5f7c3094404e1f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_4568dc15835190d3eb5f7c3094404e1f = L.map(
#                 &quot;map_4568dc15835190d3eb5f7c3094404e1f&quot;,
#                 {
#                     center: [51.4621272, -0.1162654],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fed513c6ef90f0a876e60a643b16fbdf = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_4568dc15835190d3eb5f7c3094404e1f);
#
#
#             var marker_642c5e8b75904665a12a6f01997bef32 = L.marker(
#                 [51.505024, -0.080416],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_4568dc15835190d3eb5f7c3094404e1f);
#
#
#             var icon_59319639d4c4cd22bf898f92fcf79fb5 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;briefcase&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;iconSize&quot;: [30, 30], &quot;markerColor&quot;: &quot;black&quot;, &quot;opacity&quot;: 0.9, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_642c5e8b75904665a12a6f01997bef32.setIcon(icon_59319639d4c4cd22bf898f92fcf79fb5);
#
#
#             marker_642c5e8b75904665a12a6f01997bef32.bindTooltip(
#                 `&lt;div&gt;
#                      Company
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_0ae178390435fcae7e7d8985450f31e1 = L.marker(
#                 [51.463913, -0.141862],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_4568dc15835190d3eb5f7c3094404e1f);
#
#
#             var icon_96c9e4a21103613191201abbec5eae44 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;coffee&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;markerColor&quot;: &quot;white&quot;, &quot;opacity&quot;: 0.6, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_0ae178390435fcae7e7d8985450f31e1.setIcon(icon_96c9e4a21103613191201abbec5eae44);
#
#
#             marker_0ae178390435fcae7e7d8985450f31e1.bindTooltip(
#                 `&lt;div&gt;
#                      Starbucks
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_f9e548d6f8e8cefc79a8dc6136ae54f4 = L.marker(
#                 [51.462182, -0.138337],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_4568dc15835190d3eb5f7c3094404e1f);
#
#
#             var icon_d45fda05fb708553fb7cc29b769027a6 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;coffee&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;markerColor&quot;: &quot;white&quot;, &quot;opacity&quot;: 0.6, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_f9e548d6f8e8cefc79a8dc6136ae54f4.setIcon(icon_d45fda05fb708553fb7cc29b769027a6);
#
#
#             marker_f9e548d6f8e8cefc79a8dc6136ae54f4.bindTooltip(
#                 `&lt;div&gt;
#                      Starbucks
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_7a0086e1959813cfe3d2aae3ea49587a = L.marker(
#                 [51.438958, -0.126817],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_4568dc15835190d3eb5f7c3094404e1f);
#
#
#             var icon_327af3e998b238e144c5f8a699d06083 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;coffee&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;markerColor&quot;: &quot;white&quot;, &quot;opacity&quot;: 0.6, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_7a0086e1959813cfe3d2aae3ea49587a.setIcon(icon_327af3e998b238e144c5f8a699d06083);
#
#
#             marker_7a0086e1959813cfe3d2aae3ea49587a.bindTooltip(
#                 `&lt;div&gt;
#                      Starbucks
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_17ec10b8bd2244ffb1ec739d626f352f = L.marker(
#                 [51.462136, -0.084483],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_4568dc15835190d3eb5f7c3094404e1f);
#
#
#             var icon_2b60a727fe8a223b1079c664887ed6f6 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;coffee&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;markerColor&quot;: &quot;white&quot;, &quot;opacity&quot;: 0.6, &quot;prefix&quot;: &

# %%
CA_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2bafd05b3a4175155dc51b8a6ea33a92 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2bafd05b3a4175155dc51b8a6ea33a92&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_2bafd05b3a4175155dc51b8a6ea33a92 = L.map(
#                 &quot;map_2bafd05b3a4175155dc51b8a6ea33a92&quot;,
#                 {
#                     center: [42.3731956, -71.1198561],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f6f0ecd37af315231ffcfcbbab70fcb7 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_2bafd05b3a4175155dc51b8a6ea33a92);
#
#
#             var marker_a19c778b0812e1ea61e433230f8ff627 = L.marker(
#                 [42.3731956, -71.1198561],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_2bafd05b3a4175155dc51b8a6ea33a92);
#
#
#             var icon_56b2b2dd7776b5c0910e93c3407c12e0 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;briefcase&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;iconSize&quot;: [30, 30], &quot;markerColor&quot;: &quot;black&quot;, &quot;opacity&quot;: 0.9, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_a19c778b0812e1ea61e433230f8ff627.setIcon(icon_56b2b2dd7776b5c0910e93c3407c12e0);
#
#
#             marker_a19c778b0812e1ea61e433230f8ff627.bindTooltip(
#                 `&lt;div&gt;
#                      Company
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_bdf1573286eb54a54edd12653effc6fb = L.marker(
#                 [42.373858, -71.112954],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_2bafd05b3a4175155dc51b8a6ea33a92);
#
#
#             var icon_94e7af98e8066803dfbcd828c6969445 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;coffee&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;markerColor&quot;: &quot;white&quot;, &quot;opacity&quot;: 0.6, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_bdf1573286eb54a54edd12653effc6fb.setIcon(icon_94e7af98e8066803dfbcd828c6969445);
#
#
#             marker_bdf1573286eb54a54edd12653effc6fb.bindTooltip(
#                 `&lt;div&gt;
#                      Starbucks
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_1e881a969dbbe2ea15447beccb1ddc9c = L.marker(
#                 [42.386097, -71.114168],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_2bafd05b3a4175155dc51b8a6ea33a92);
#
#
#             var icon_17c8d4482bba2f2af1be4c78cbf90f5e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;coffee&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;markerColor&quot;: &quot;white&quot;, &quot;opacity&quot;: 0.6, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_1e881a969dbbe2ea15447beccb1ddc9c.setIcon(icon_17c8d4482bba2f2af1be4c78cbf90f5e);
#
#
#             marker_1e881a969dbbe2ea15447beccb1ddc9c.bindTooltip(
#                 `&lt;div&gt;
#                      Starbucks
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_eebaad66825165ced9c1e069adcfcf1c = L.marker(
#                 [42.363412, -71.130402],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_2bafd05b3a4175155dc51b8a6ea33a92);
#
#
#             var icon_b4a97f4527be0033682b584ad626facb = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;coffee&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;markerColor&quot;: &quot;white&quot;, &quot;opacity&quot;: 0.6, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_eebaad66825165ced9c1e069adcfcf1c.setIcon(icon_b4a97f4527be0033682b584ad626facb);
#
#
#             marker_eebaad66825165ced9c1e069adcfcf1c.bindTooltip(
#                 `&lt;div&gt;
#                      Starbucks
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_708ee8f6ddb5ce2f3504091ec9730312 = L.marker(
#                 [42.358, -71.115075],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_2bafd05b3a4175155dc51b8a6ea33a92);
#
#
#             var icon_b9fc809ebec8c70a745605989161030d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;coffee&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;markerColor&quot;: &quot;white&quot;, &quot;opacity&quot;: 0.6, &quot;prefix&quo

# %%
CH_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ab4b5fb11551f32f3bf46a65c703f1b4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ab4b5fb11551f32f3bf46a65c703f1b4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_ab4b5fb11551f32f3bf46a65c703f1b4 = L.map(
#                 &quot;map_ab4b5fb11551f32f3bf46a65c703f1b4&quot;,
#                 {
#                     center: [41.869276, -87.626694],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3d1e5f7aa144e4ba436445ac634772f8 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ab4b5fb11551f32f3bf46a65c703f1b4);
#
#
#             var marker_9e379636dbf9a7cf934e4abfe0881733 = L.marker(
#                 [41.869276, -87.626694],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_ab4b5fb11551f32f3bf46a65c703f1b4);
#
#
#             var icon_93f1f533a29c6c82c8adfc62b28d9fc1 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;briefcase&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;iconSize&quot;: [30, 30], &quot;markerColor&quot;: &quot;black&quot;, &quot;opacity&quot;: 0.9, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_9e379636dbf9a7cf934e4abfe0881733.setIcon(icon_93f1f533a29c6c82c8adfc62b28d9fc1);
#
#
#             marker_9e379636dbf9a7cf934e4abfe0881733.bindTooltip(
#                 `&lt;div&gt;
#                      Company
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_7e2bbbe7a1aa91670177ced1ae1747c6 = L.marker(
#                 [41.878503, -87.639922],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_ab4b5fb11551f32f3bf46a65c703f1b4);
#
#
#             var icon_1a83a7075a947bc0f652b7b7370e9080 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;coffee&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;markerColor&quot;: &quot;white&quot;, &quot;opacity&quot;: 0.6, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_7e2bbbe7a1aa91670177ced1ae1747c6.setIcon(icon_1a83a7075a947bc0f652b7b7370e9080);
#
#
#             marker_7e2bbbe7a1aa91670177ced1ae1747c6.bindTooltip(
#                 `&lt;div&gt;
#                      Starbucks Express
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_cc105e174c003c2e27c396f82301a3d9 = L.marker(
#                 [41.884305, -87.642556],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_ab4b5fb11551f32f3bf46a65c703f1b4);
#
#
#             var icon_039b6207780485446ce512375a157252 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;coffee&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;markerColor&quot;: &quot;white&quot;, &quot;opacity&quot;: 0.6, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_cc105e174c003c2e27c396f82301a3d9.setIcon(icon_039b6207780485446ce512375a157252);
#
#
#             marker_cc105e174c003c2e27c396f82301a3d9.bindTooltip(
#                 `&lt;div&gt;
#                      Starbucks Coffee Company - Regional Office
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_6e6f3bb6521feaf2b660a0070ea78fbc = L.marker(
#                 [41.862063, -87.627012],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_ab4b5fb11551f32f3bf46a65c703f1b4);
#
#
#             var icon_49796e1cc43cc582692822c3cb1f0354 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;graduation-cap&quot;, &quot;iconColor&quot;: &quot;yellow&quot;, &quot;markerColor&quot;: &quot;pink&quot;, &quot;opacity&quot;: 0.6, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_6e6f3bb6521feaf2b660a0070ea78fbc.setIcon(icon_49796e1cc43cc582692822c3cb1f0354);
#
#
#             marker_6e6f3bb6521feaf2b660a0070ea78fbc.bindTooltip(
#                 `&lt;div&gt;
#                      KinderCare Learning Center
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_418dcac337a4eb61c9305196d1e046fa = L.marker(
#                 [41.878239, -87.649239],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_ab4b5fb11551f32f3bf46a65c703f1b4);
#
#
#             var icon_623f765760aef501f059ea8e91b7170a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;graduation-cap&quot;, &quot;iconColor&quot;: &quot;yellow&quot;, &quot;marker

# %% [markdown]
# # Weighting the results

# %% [markdown]
# - First of all we delete the first element of each list, that correspond to our company details.

# %%
df_SF = df_SF.iloc[1:]
df_CA = df_CA.iloc[1:]
df_CH = df_CH.iloc[1:]
df_SE = df_SE.iloc[1:]
df_LO = df_LO.iloc[1:]

# %% [markdown]
# - In order to to get the final result for each city, we just apply a simple math formulation to the grouped data for each city. The one with the lowest score will be the winner.

# %% [markdown]
# # San Francisco

# %%
index = pd.Index(['Airport','Basketball arena','Club','Coffee','Pet hairdresser',"Preschool","Vegan restaurant"], name = "Category")
SF_weight = pd.DataFrame({'Weight factor':[0.1, 0.2, 0.05, 0.1, 0.2, 0.05, 0.3]}, index=index)
SF_weight.insert(1, 'Radius', [30000, 5000, 3000, 3000, 3000, 3000,3000])

SF_weight = fun.get_weight(SF_weight, df_SF)

print(fun.final_result(SF_weight, "San Francisco"))
print(SF_weight)
# Out:
# The final result for San Francisco is 0.37
#                   Weight factor  Radius       Mean       Max       Min  \
# Airport                    0.10   30000  18352.690  18605.79  18099.59
# Basketball arena           0.20    5000   2470.210   2470.21   2470.21
# Club                       0.05    3000   1816.876   2613.47    945.47
# Coffee                     0.10    3000    544.230    857.26     70.44
# Pet hairdresser            0.20    3000    698.642   1134.74    398.67
# Preschool                  0.05    3000   1474.100   2907.50    521.78
# Vegan restaurant           0.30    3000    930.075   1593.07    224.02
#
#                   Final Result
# Airport                   0.06
# Basketball arena          0.10
# Club                      0.03
# Coffee                    0.02
# Pet hairdresser           0.05
# Preschool                 0.02
# Vegan restaurant          0.09

# %% [markdown]
# # Cambridge

# %%
index = pd.Index(['Airport','Basketball arena','Club','Coffee','Pet hairdresser',"Preschool","Vegan restaurant"], name = "Category")
CA_weight = pd.DataFrame({'Weight factor':[0.1, 0.2, 0.05, 0.1, 0.2, 0.05, 0.3]}, index=index)
CA_weight.insert(1, 'Radius', [30000, 5000, 3000, 3000, 3000, 3000,3000])

CA_weight = fun.get_weight(CA_weight, df_CA)
fun.final_result(CA_weight, "Cambridge")
# Out:
# 'The final result for Cambridge is 0.65'

# %% [markdown]
# # Chicago

# %%
index = pd.Index(['Airport','Basketball arena','Club','Coffee','Pet hairdresser',"Preschool","Vegan restaurant"], name = "Category")
CH_weight = pd.DataFrame({'Weight factor':[0.1, 0.2, 0.05, 0.1, 0.2, 0.05, 0.3]}, index=index)
CH_weight.insert(1, 'Radius', [30000, 5000, 3000, 3000, 3000, 3000,3000])
CH_weight = fun.get_weight(CH_weight, df_CH)

fun.final_result(CH_weight, "Chicago")
# Out:
# 'The final result for Chicago is 0.56'

# %% [markdown]
# # Seattle

# %%
index = pd.Index(['Airport','Basketball arena','Club','Coffee','Pet hairdresser',"Preschool","Vegan restaurant"], name = "Category")
SE_weight = pd.DataFrame({'Weight factor':[0.1, 0.2, 0.05, 0.1, 0.2, 0.05, 0.3]}, index=index)
SE_weight.insert(1, 'Radius', [30000, 5000, 3000, 3000, 3000, 3000,3000])

SE_weight = fun.get_weight(SE_weight, df_SE)
fun.final_result(SE_weight, "Seattle")
# Out:
# 'The final result for Seattle is 0.52'

# %% [markdown]
# # London

# %%
index = pd.Index(['Airport','Basketball arena','Club','Coffee','Pet hairdresser',"Preschool","Vegan restaurant"], name = "Category")
LO_weight = pd.DataFrame({'Weight factor':[0.1, 0.2, 0.05, 0.1, 0.2, 0.05, 0.3]}, index=index)
LO_weight.insert(1, 'Radius', [30000, 5000, 3000, 3000, 3000, 3000,3000])

LO_weight = fun.get_weight(LO_weight, df_LO)
fun.final_result(LO_weight, "London")
# Out:
# 'The final result for London is 1.28'

# %% [markdown]
# # The city selected is San Francisco
